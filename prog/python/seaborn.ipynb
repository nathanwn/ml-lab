# %%
import numpy as np
import seaborn as sns

# %%
# %matplotlib inline

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # 1. Quantitative plots

# %% [markdown]
# ## 1.1. Histogram using `displot`

# %% [markdown]
# Read: https://seaborn.pydata.org/tutorial/distributions.html

# %%
sns.displot(iris['sepal_length'])

# %%
sns.displot(iris['sepal_length'], bins=9)

# %%
sns.displot(x='sepal_length', hue='species', data=iris)

# %%
sns.displot(x='sepal_length', hue='species', data=iris, multiple='dodge')

# %%
sns.displot(x='sepal_length', hue='species', data=iris, element='step', bins=10)

# %% [markdown]
# ## 1.2. Rug plot

# %%
sns.rugplot(data=iris, x='sepal_length', hue='species')
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %% [markdown]
# ## 1.3. Scatterplot

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# ## 1.4. Pairplot

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(iris, hue='species')

# %% [markdown]
# ## 1.5. Custom pairplot

# %%
g = sns.PairGrid(iris, hue='species')
g.map_diag(sns.histplot)
g.map_offdiag(sns.kdeplot)
g.add_legend()

# %% [markdown]
# # 2. Categorical Plots

# %% [markdown]
# ## 2.1. Bar plot

# %%
sns.barplot(x='species', y='sepal_length', data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.barplot(x='species', y='sepal_length', data=iris, estimator=np.std)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# ## 2.2. Boxplot

# %%
sns.boxplot(x='species', y='sepal_length', data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %% [markdown]
# # 2.3. Heatmap

# %% [markdown]
# ### 2.3.1. Heatmap for correlation table

# %%
iris.corr() # compute pair-wise correlations of columns
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2.3.2. Heatmap for pivot table

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pivot_table = flights.pivot_table(index='month', columns='year', values='passengers')

# %%
pivot_table
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(pivot_table, cmap='coolwarm', linecolor='white', linewidth=1)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %% [markdown]
# ### 2.3.3. Clustermap

# %%
sns.clustermap(pivot_table, cmap='coolwarm')

# %%
sns.clustermap(pivot_table, cmap='coolwarm', standard_scale=1)
